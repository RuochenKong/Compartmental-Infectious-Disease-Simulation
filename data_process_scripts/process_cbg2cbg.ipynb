# %%
import os
import numpy as np
import pandas as pd

# %%
ORI_DATA = 'src_data/cbg2cbg-1.csv'
OUT_DATA = 'src_data/cbg2cbg.csv'

# %%
fout = open(OUT_DATA, 'w')
title = True
with open(ORI_DATA, 'r') as f:
    for line in f.readlines():
        if title:
            fout.write(line)
            title = False
            continue
        line = line.split(',')
        line[0] = '%012d'%(int(line[0]))
        line[1] = '%012d'%(int(line[1]))
        fout.write(','.join(line))
fout.close()

# %%
tran_df = transport_data = pd.read_csv(OUT_DATA,dtype={'poi_cbg_source': str, 'poi_cbg_destination':str})

# %%
tran_df['poi_cbg_source'] = tran_df['poi_cbg_source'].apply(lambda x: x[:5])
tran_df['poi_cbg_destination'] = tran_df['poi_cbg_destination'].apply(lambda x: x[:5])

# %%
tran_cum_df = tran_df.groupby(['poi_cbg_source', 'poi_cbg_destination']).sum().reset_index()

# %%
sum_des = tran_cum_df.groupby('poi_cbg_source')['des_prob'].sum()
sum_des = sum_des.rename('cum_des')
cum_df = tran_cum_df.join(sum_des, on = 'poi_cbg_source')

# %%
sum_src = tran_cum_df.groupby('poi_cbg_destination')['src_prob'].sum()
sum_src = sum_src.rename('cum_src')
cum_df = cum_df.join(sum_src, on = 'poi_cbg_destination')

# %%
cum_df['src_prob'] = cum_df['src_prob']/cum_df['cum_src']

# %%
cum_df['des_prob'] = cum_df['des_prob']/cum_df['cum_des']

# %%
cum_df = cum_df[['poi_cbg_source','poi_cbg_destination','src_prob', 'des_prob']].reset_index(drop = True)
cum_df
# Out:
#        poi_cbg_source poi_cbg_destination  src_prob  des_prob
# 0               01001               01001  0.755235  0.455936
# 1               01001               01003  0.000718  0.004887
# 2               01001               01007  0.000299  0.000240
# 3               01001               01013  0.006786  0.000481
# 4               01001               01015  0.000075  0.000923
# ...               ...                 ...       ...       ...
# 337089          56045               56025  0.000098  0.006996
# 337090          56045               56027  0.020090  0.009179
# 337091          56045               56031  0.000363  0.000627
# 337092          56045               56033  0.001299  0.001254
# 337093          56045               56045  0.908054  0.458346
#
# [337094 rows x 4 columns]

# %%
cum_df.to_csv('src_data/county2county.csv', index = False)

# %%
cum_df
# Out:
#        poi_cbg_source poi_cbg_destination  src_prob  des_prob
# 0               01001               01001  0.755235  0.455936
# 1               01001               01003  0.000718  0.004887
# 2               01001               01007  0.000299  0.000240
# 3               01001               01013  0.006786  0.000481
# 4               01001               01015  0.000075  0.000923
# ...               ...                 ...       ...       ...
# 337089          56045               56025  0.000098  0.006996
# 337090          56045               56027  0.020090  0.009179
# 337091          56045               56031  0.000363  0.000627
# 337092          56045               56033  0.001299  0.001254
# 337093          56045               56045  0.908054  0.458346
#
# [337094 rows x 4 columns]

# %%
list(cum_df.groupby('poi_cbg_source').groups.keys())
# Out:
# ['01001',
#  '01003',
#  '01005',
#  '01007',
#  '01009',
#  '01011',
#  '01013',
#  '01015',
#  '01017',
#  '01019',
#  '01021',
#  '19121',
#  '19123',
#  '19125',
#  '19127',
#  '19129',
#  '19131',
#  '19133',
#  '19135',
#  '19137',
#  '19139',
#  '19141',
#  '19143',
#  '19145',
#  '19147',
#  '19149',
#  '19151',
#  '19153',
#  '19155',
#  '19157',
#  '19159',
#  '19161',
#  '19163',
#  '19165',
#  '19167',
#  '19169',
#  '19171',
#  '19173',
#  '19175',
#  '19177',
#  '19179',
#  '19181',
#  '19183',
#  '19185',
#  '19187',
#  '19189',
#  '19191',
#  '19193',
#  '19195',
#  '19197',
#  '20001',
#  '20003',
#  '20005',
#  '20007',
#  '20009',
#  '20011',
#  '20013',
#  '20015',
#  '20017',
#  '20019',
#  '20021',
#  '20023',
#  '20025',
#  '20027',
#  '20029',
#  '20031',
#  '20033',
#  '20035',
#  '20037',
#  '20039',
#  '20041',
#  '20043',
#  '20045',
#  '20047',
#  '20049',
#  '20051',
#  '20053',
#  '20055',
#  '20057',
#  '20059',
#  '20061',
#  '20063',
#  '20065',
#  '20067',
#  '20069',
#  '20071',
#  '20073',
#  '20075',
#  '20077',
#  '20079',
#  '20081',
#  '20083',
#  '20085',
#  '20087',
#  '20089',
#  '20091',
#  '20093',
#  '20095',
#  '20097',
#  '20099',
#  '20101',
#  '20103',
#  '20105',
#  '20107',
#  '20109',
#  '20111',
#  '20113',
#  '20115',
#  '20117',
#  '20119',
#  '20121',
#  '20123',
#  '20125',
#  '20127',
#  '20129',
#  '20131',
#  '20133',
#  '20135',
#  '20137',
#  '20139',
#  '20141',
#  '20143',
#  '20145',
#  '20147',
#  '20149',
#  '20151',
#  '20153',
#  '20155',
#  '20157',
#  '20159',
#  '20161',
#  '20163',
#  '20165',
#  '20167',
#  '20169',
#  '20171',
#  '20173',
#  '20175',
#  '20177',
#  '20179',
#  '20181',
#  '20183',
#  '20185',
#  '20187',
#  '20189',
#  '20191',
#  '20193',
#  '20195',
#  '20197',
#  '20199',
#  '20201',
#  '20203',
#  '20205',
#  '20207',
#  '20209',
#  '21001',
#  '21003',
#  '21005',
#  '21007',
#  '21009',
#  '21011',
#  '21013',
#  ...]

# %%
cum_df.groupby('poi_cbg_source')['des_prob'].sum()
# Out:
# poi_cbg_source
# 01001020100    1.0
# 01001020200    1.0
# 01001020300    1.0
# 01001020400    1.0
# 01001020500    1.0
#               ...
# 56043000200    1.0
# 56043000301    1.0
# 56043000302    1.0
# 56045951100    1.0
# 56045951300    1.0
# Name: des_prob, Length: 72581, dtype: float64

# %%
ORI_DATA = 'src_data/mpox_2quick_weekly_pgraph.csv'
OUT_DATA = 'src_data/cbg2cbg.csv'

# %%
fout = open(OUT_DATA, 'w')
with open(ORI_DATA, 'r') as f:
    for line in f.readlines():
        if 'CA' not in line:
            fout.write(line)
fout.close()

# %%
OUT_DIR = 'src_data/cbg_data/'
if not os.path.exists(OUT_DIR):
    os.makedirs(OUT_DIR)

# %%
with open(OUT_DIR + 'cbg_name', 'w') as fout:
    isheader = True
    cbgNames = set()
    with open(OUT_DATA, 'r') as f:
        for line in f.readlines():
            if isheader:
                isheader = False
                continue
            cbgNames.add(line.strip().split(',')[0])
            cbgNames.add(line.strip().split(',')[1])
    cbgNames = list(cbgNames)
    for cbg in cbgNames:
        fout.write(cbg + '\n')

# %%
OUT_DIR2 = 'src_data/cbg_data/cbg2cbg/'
if not os.path.exists(OUT_DIR2):
    os.makedirs(OUT_DIR2)

# %%
import random

# %%
def get_ramdom_dest(src_df):
    randval = random.random()
    cumprob = src_df['probability'].cumsum()
    sumprob = src_df['probability'].sum()
    if sumprob == 0:
        return 
    randval *= sumprob
    checkprob = 0
    for des, prob in zip(src_df['poi_cbg_destination'], cumprob):
        if checkprob == prob:
            continue
        if randval < prob:
            return des
    return src_df.loc[-1,'poi_cbg_destination']

# %%
def recalculate(group):
    group = group.copy()
    group.drop(columns=['poi_cbg_source'], inplace=True)

    sumprob = group['probability'].sum()
    if abs(sumprob) < 1e-18:  # Handle very small sums close to zero
        return group
    group['probability'] = group['probability'].div(sumprob)

    return group

# %%
chunked_data = pd.read_csv(OUT_DATA, chunksize=100000)
chunk_list = []
for chunk in chunked_data:
    chunk_list.append(chunk)
df = pd.concat(chunk_list)

# %%
df
# Out:
#           poi_cbg_source poi_cbg_destination  number_of_visitors  probability
# 0            10010201001         10010201001                  33     0.038239
# 1            10010201001         10010202001                  15     0.017381
# 2            10010201001         10010202002                  36     0.041715
# 3            10010201001         10010203002                 113     0.130939
# 4            10010201001         10010204003                   6     0.006952
# ...                  ...                 ...                 ...          ...
# 17423096    560459513003        560279572003                   6     0.008876
# 17423097    560459513003        560459511002                   3     0.004438
# 17423098    560459513003        560459513001                  69     0.102071
# 17423099    560459513003        560459513002                 229     0.338757
# 17423100    560459513003        560459513003                  50     0.073964
#
# [17423101 rows x 4 columns]

# %%
get_ramdom_dest(df.groupby('poi_cbg_source').get_group(10010201001))
# Out:
# 0.08194242474010716
# 0.9826187717265332
# 0.08051816475041798
# 10010201001 0.0382387022016222
# 10010202001 0.0382387022016222
# 10010202002 0.0799536500579373
# 10010203002 0.21089223638470428
# 10010203002

# %%
remove_idx = df[df['poi_cbg_destination'] == 10010202001].index
df.loc[remove_idx, 'probability'] = 0
df
# Out:
#           poi_cbg_source poi_cbg_destination  number_of_visitors  probability
# 0            10010201001         10010201001                  33     0.038239
# 1            10010201001         10010202001                  15     0.000000
# 2            10010201001         10010202002                  36     0.041715
# 3            10010201001         10010203002                 113     0.130939
# 4            10010201001         10010204003                   6     0.006952
# ...                  ...                 ...                 ...          ...
# 17423096    560459513003        560279572003                   6     0.008876
# 17423097    560459513003        560459511002                   3     0.004438
# 17423098    560459513003        560459513001                  69     0.102071
# 17423099    560459513003        560459513002                 229     0.338757
# 17423100    560459513003        560459513003                  50     0.073964
#
# [17423101 rows x 4 columns]
